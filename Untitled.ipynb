# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv('Train_SU63ISt.csv')
test=pd.read_csv('Test_0qrQsBZ.csv')

# %%
train_original=train.copy()
test_original=test.copy()

# %%
train.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
test.head()
# Out:
#       ID          Datetime
# 0  18288  26-09-2014 00:00
# 1  18289  26-09-2014 01:00
# 2  18290  26-09-2014 02:00
# 3  18291  26-09-2014 03:00
# 4  18292  26-09-2014 04:00

# %%
train.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %%
test.dtypes
# Out:
# ID           int64
# Datetime    object
# dtype: object

# %%
train.shape
# Out:
# (18288, 3)

# %%
test.shape
# Out:
# (5112, 2)

# %% [markdown]
# We will extract the time and date from the Datetime. We have seen earlier that the data type of Datetime is object. So first of all we have to change the data type to datetime format otherwise we can not extract features from it.

# %%
train['Datetime']=pd.to_datetime(train.Datetime,format='%d-%m-%Y %H:%M')

# %%
train.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
test['Datetime']=pd.to_datetime(test.Datetime,format='%d-%m-%Y %H:%M')
train_original['Datetime']=pd.to_datetime(train_original.Datetime,format='%d-%m-%Y %H:%M')
test_original['Datetime']=pd.to_datetime(test_original.Datetime,format='%d-%m-%Y %H:%M')

# %%
train.dtypes,test.dtypes,train_original.dtypes,test_original.dtypes
# Out:
# (ID                   int64
#  Datetime    datetime64[ns]
#  Count                int64
#  dtype: object, ID                   int64
#  Datetime    datetime64[ns]
#  dtype: object, ID                   int64
#  Datetime    datetime64[ns]
#  Count                int64
#  dtype: object, ID                   int64
#  Datetime    datetime64[ns]
#  dtype: object)

# %%
train['day of week']=train['Datetime'].dt.dayofweek

# %%
temp=train['Datetime']

# %%
def apply01(row):
    if row.dayofweek==5 or row.dayofweek==6:
        return 1
    else:
        return 0

# %%
temp2=train['Datetime'].apply(apply01)

# %%
train['weekend']=temp2

# %%
train.head()
# Out:
#    ID            Datetime  Count  day of week  weekend
# 0   0 2012-08-25 00:00:00      8            5        1
# 1   1 2012-08-25 01:00:00      2            5        1
# 2   2 2012-08-25 02:00:00      6            5        1
# 3   3 2012-08-25 03:00:00      2            5        1
# 4   4 2012-08-25 04:00:00      2            5        1

# %%
train.index=train['Datetime']

# %%
train.head()
# Out:
#                      ID            Datetime  Count  day of week  weekend
# Datetime
# 2012-08-25 00:00:00   0 2012-08-25 00:00:00      8            5        1
# 2012-08-25 01:00:00   1 2012-08-25 01:00:00      2            5        1
# 2012-08-25 02:00:00   2 2012-08-25 02:00:00      6            5        1
# 2012-08-25 03:00:00   3 2012-08-25 03:00:00      2            5        1
# 2012-08-25 04:00:00   4 2012-08-25 04:00:00      2            5        1

# %%
df=train.drop('ID',1)

# %%
plt.figure(figsize=(16,5))
plt.plot(df['Count'],label='Passenge Counts')
plt.title('Time Series')
plt.xlabel('Time(year-month)')
plt.ylabel('Passenger Counts')
plt.legend()

# %%
for i in (train,train_original, test, test_original):
    i['year']=i.Datetime.dt.year 
    i['month']=i.Datetime.dt.month 
    i['day']=i.Datetime.dt.day
    i['Hour']=i.Datetime.dt.hour

# %%
train.head()
# Out:
#                      ID            Datetime  Count  day of week  weekend  \
# Datetime
# 2012-08-25 00:00:00   0 2012-08-25 00:00:00      8            5        1
# 2012-08-25 01:00:00   1 2012-08-25 01:00:00      2            5        1
# 2012-08-25 02:00:00   2 2012-08-25 02:00:00      6            5        1
# 2012-08-25 03:00:00   3 2012-08-25 03:00:00      2            5        1
# 2012-08-25 04:00:00   4 2012-08-25 04:00:00      2            5        1
#
#                      year  month  day  Hour
# Datetime
# 2012-08-25 00:00:00  2012      8   25     0
# 2012-08-25 01:00:00  2012      8   25     1
# 2012-08-25 02:00:00  2012      8   25     2
# 2012-08-25 03:00:00  2012      8   25     3
# 2012-08-25 04:00:00  2012      8   25     4

# %%
train.groupby('year')['Count'].mean().plot.bar()

# %%
train.groupby('month')['Count'].mean().plot.bar()

# %%
temp=train.groupby(['year', 'month'])['Count'].mean()
temp.plot(figsize=(15,5), title= 'Passenger Count(Monthwise)', fontsize=14)

# %%
temp.sort_values(ascending=False)
# Out:
# year  month
# 2014  9        468.433333
#       8        389.981183
#       7        343.354839
#       6        316.113889
#       5        264.497312
#       4        240.955556
#       2        200.202381
#       3        183.994624
#       1        167.204301
# 2013  12       157.387097
#       11       141.000000
#       10       139.932796
#       9        120.744444
#       8        100.137097
#       7         74.787634
#       6         57.333333
#       5         45.612903
#       4         34.405556
#       3         23.588710
#       2         22.190476
#       1         18.430108
# 2012  11        15.827778
#       12        15.680108
#       10        10.986559
#       9          4.444444
#       8          2.952381
# Name: Count, dtype: float64

# %%
train.groupby('day')['Count'].mean().plot.bar()

# %%
train.groupby('Hour')['Count'].mean().plot.bar()

# %%
train.groupby('weekend')['Count'].mean().plot.bar()

# %% [markdown]
# It can be inferred from the above plot that the traffic is more on weekdays as compared to weekends which validates our hypothesis.
#
#
# 0 is the starting of the week, i.e., 0 is Monday and 6 is Sunday.

# %%
train.groupby('day of week')['Count'].mean().plot.bar()

# %% [markdown]
# From the above bar plot, we can infer that the passenger count is less for saturday and sunday as compared to the other days of the week.

# %%
train=train.drop('ID',axis=1)

#hourly time series
hourly=train.resample('H').mean()

#daily time series
daily=train.resample('D').mean()

#monthly time series
monthly=train.resample('M').mean()

#weekly time series
weekly=train.resample('W').mean()

# %%
hourly.head()
# Out:
#                      Count  day of week  weekend  year  month  day  Hour
# Datetime
# 2012-08-25 00:00:00      8            5        1  2012      8   25     0
# 2012-08-25 01:00:00      2            5        1  2012      8   25     1
# 2012-08-25 02:00:00      6            5        1  2012      8   25     2
# 2012-08-25 03:00:00      2            5        1  2012      8   25     3
# 2012-08-25 04:00:00      2            5        1  2012      8   25     4

# %%
daily.head()
# Out:
#                Count  day of week  weekend    year  month   day  Hour
# Datetime
# 2012-08-25  3.166667          5.0      1.0  2012.0    8.0  25.0  11.5
# 2012-08-26  3.666667          6.0      1.0  2012.0    8.0  26.0  11.5
# 2012-08-27  2.583333          0.0      0.0  2012.0    8.0  27.0  11.5
# 2012-08-28  2.416667          1.0      0.0  2012.0    8.0  28.0  11.5
# 2012-08-29  2.500000          2.0      0.0  2012.0    8.0  29.0  11.5

# %%
weekly.head()
# Out:
#                Count  day of week   weekend    year     month        day  Hour
# Datetime
# 2012-08-26  3.416667          5.5  1.000000  2012.0  8.000000  25.500000  11.5
# 2012-09-02  3.345238          3.0  0.285714  2012.0  8.285714  21.142857  11.5
# 2012-09-09  3.654762          3.0  0.285714  2012.0  9.000000   6.000000  11.5
# 2012-09-16  3.119048          3.0  0.285714  2012.0  9.000000  13.000000  11.5
# 2012-09-23  4.714286          3.0  0.285714  2012.0  9.000000  20.000000  11.5

# %%
monthly.head()
# Out:
#                 Count  day of week   weekend    year  month   day  Hour
# Datetime
# 2012-08-31   2.952381     3.000000  0.285714  2012.0    8.0  28.0  11.5
# 2012-09-30   4.444444     3.166667  0.333333  2012.0    9.0  15.5  11.5
# 2012-10-31  10.986559     2.806452  0.258065  2012.0   10.0  16.0  11.5
# 2012-11-30  15.827778     3.033333  0.266667  2012.0   11.0  15.5  11.5
# 2012-12-31  15.680108     3.064516  0.322581  2012.0   12.0  16.0  11.5

# %%
fig, axs = plt.subplots(4,1)

hourly.Count.plot(figsize=(20,10), title= 'Hourly', fontsize=14, ax=axs[0])
daily.Count.plot(figsize=(20,10), title= 'Daily', fontsize=14, ax=axs[1])
weekly.Count.plot(figsize=(20,10), title= 'Weekly', fontsize=14, ax=axs[2])
monthly.Count.plot(figsize=(20,10), title= 'Monthly', fontsize=14, ax=axs[3])

# %% [markdown]
# so 1st we converting train and test as daily basis

# %%
train.head()
# Out:
#                                Datetime  Count  day of week  weekend  year  \
# Datetime
# 2012-08-25 00:00:00 2012-08-25 00:00:00      8            5        1  2012
# 2012-08-25 01:00:00 2012-08-25 01:00:00      2            5        1  2012
# 2012-08-25 02:00:00 2012-08-25 02:00:00      6            5        1  2012
# 2012-08-25 03:00:00 2012-08-25 03:00:00      2            5        1  2012
# 2012-08-25 04:00:00 2012-08-25 04:00:00      2            5        1  2012
#
#                      month  day  Hour
# Datetime
# 2012-08-25 00:00:00      8   25     0
# 2012-08-25 01:00:00      8   25     1
# 2012-08-25 02:00:00      8   25     2
# 2012-08-25 03:00:00      8   25     3
# 2012-08-25 04:00:00      8   25     4

# %%
test.head()
# Out:
#       ID            Datetime  year  month  day  Hour
# 0  18288 2014-09-26 00:00:00  2014      9   26     0
# 1  18289 2014-09-26 01:00:00  2014      9   26     1
# 2  18290 2014-09-26 02:00:00  2014      9   26     2
# 3  18291 2014-09-26 03:00:00  2014      9   26     3
# 4  18292 2014-09-26 04:00:00  2014      9   26     4

# %%
test.index=test.Datetime
#Converting to daily mean
test=test.resample('D').mean()
train=train.resample('D').mean()

# %%
test.head()
# Out:
#                  ID    year  month   day  Hour
# Datetime
# 2014-09-26  18299.5  2014.0    9.0  26.0  11.5
# 2014-09-27  18323.5  2014.0    9.0  27.0  11.5
# 2014-09-28  18347.5  2014.0    9.0  28.0  11.5
# 2014-09-29  18371.5  2014.0    9.0  29.0  11.5
# 2014-09-30  18395.5  2014.0    9.0  30.0  11.5

# %%
train.head()
# Out:
#                Count  day of week  weekend    year  month   day  Hour
# Datetime
# 2012-08-25  3.166667          5.0      1.0  2012.0    8.0  25.0  11.5
# 2012-08-26  3.666667          6.0      1.0  2012.0    8.0  26.0  11.5
# 2012-08-27  2.583333          0.0      0.0  2012.0    8.0  27.0  11.5
# 2012-08-28  2.416667          1.0      0.0  2012.0    8.0  28.0  11.5
# 2012-08-29  2.500000          2.0      0.0  2012.0    8.0  29.0  11.5

# %% [markdown]
# # Model Building:
#
# We can see that the time series is becoming more and more stable when we are aggregating it on daily, weekly and monthly basis.

# %% [markdown]
# But it would be difficult to convert the monthly and weekly predictions to hourly predictions, as first we have to convert the monthly predictions to weekly, weekly to daily and daily to hourly predictions, which will become very expanded process. So, we will work on the daily time series.

# %%
Train=train.ix['2012-08-05':'2014-06-24']
valid=train.ix['2014-06-25':'2014-09-25']
Train=Train.resample('D').mean()
valid=valid.resample('D').mean()

# %%
Train.Count.plot(figsize=(20,8), title= 'Daily Ridership', fontsize=14, label='train')
valid.Count.plot(figsize=(20,8), title= 'Daily Ridership', fontsize=14, label='valid')
plt.xlabel("Datetime")
plt.ylabel("Passenger count")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# here blue part represent the train

# %% [markdown]
# # MODELING TECHNIQUES
#
#
#
# # i) Naive Approach
# # ii) Moving Average
# # iii) Simple Exponential Smoothing
# # iv) Holt’s Linear Trend Model

# %% [markdown]
# # Naive Approach
#
#
# In this forecasting technique, we assume that the next expected point is equal to the last observed point
#
# # ![title](download.jpg)

# %%
dd=np.asarray(Train.Count)

# %%
y_pred=valid.copy()
y_pred['naive']=dd[len(dd)-1]
plt.figure(figsize=(20,6))
plt.plot(Train.index,Train.Count,label='Train')
plt.plot(valid.index,valid.Count,label='Valid')
plt.plot(y_pred.index,y_pred.naive,label='Naive Prediction')

# %% [markdown]
# We can calculate how accurate our predictions are using rmse(Root Mean Square Error).
#
#
# rmse is the standard deviation of the residuals.
#
#
# Residuals are a measure of how far from the regression line data points are.
#
#
# The formula for rmse is:
#
# (squareroot of mean of sum of square of  y_actual-y_pred)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms=sqrt(mean_squared_error(valid.Count,y_pred.naive))
rms
# Out:
# 111.79050467496724

# %% [markdown]
# # Moving Average

# %% [markdown]
# # ![title](download1.png)

# %% [markdown]
# Here the predictions are made on the basis of the average of last few points instead of taking all the previously known values.
#
# Lets try the rolling mean for last 10, 20, 50 days and visualize the results.

# %%
y_pred_avg=valid.copy()
y_pred_avg['moving_avg_forecast']=Train['Count'].iloc[-10:].mean() # mean of last 10 Count
plt.figure(figsize=(15,5))
plt.plot(Train['Count'],label='Train')
plt.plot(valid['Count'],label='valid')
plt.plot(y_pred_avg['moving_avg_forecast'],label='Moving Average Forecast using 10 observations')
plt.legend()
plt.show()

y_pred_avg=valid.copy()
y_pred_avg['moving_avg_forecast']=Train['Count'].iloc[-20:].mean() # mean of last 50 Count
plt.figure(figsize=(15,5))
plt.plot(Train['Count'],label='Train')
plt.plot(valid['Count'],label='valid')
plt.plot(y_pred_avg['moving_avg_forecast'],label='Moving Average Forecast using 20 observations')
plt.legend()
plt.show()

y_pred_avg=valid.copy()
y_pred_avg['moving_avg_forecast']=Train['Count'].iloc[-50:].mean() # mean of last 50 Count
plt.figure(figsize=(15,5))
plt.plot(Train['Count'],label='Train')
plt.plot(valid['Count'],label='valid')
plt.plot(y_pred_avg['moving_avg_forecast'],label='Moving Average Forecast using 50 observations')
plt.legend()
plt.show()

# %% [markdown]
# We took the average of last 10, 20 and 50 observations and predicted based on that. This value can be changed in the above code in .rolling().mean() part. We can see that the predictions are getting weaker as we increase the number of observations.

# %%
rms=sqrt(mean_squared_error(valid['Count'],y_pred_avg['moving_avg_forecast']))  #on 50 day
rms
# Out:
# 144.19175679986793

# %%
y_pred_avg['mean_squared_error']=Train['Count'].rolling(10).mean().iloc[-1]  #average of last 10 count
rms=sqrt(mean_squared_error(valid['Count'],y_pred_avg['mean_squared_error']))  #on 10 day
rms
# Out:
# 134.23733308950264

# %% [markdown]
# # Simple Exponential Smoothing

# %% [markdown]
# In this technique, we assign larger weights to more recent observations than to observations from the distant past.
#
#
# The weights decrease exponentially as observations come from further in the past, the smallest weights are associated with the oldest observations.

# %% [raw]
# NOTE - If we give the entire weight to the last observed value only, this method will be similar to the naive approach. So, we can say that naive approach is also a simple exponential smoothing technique where the entire weight is given to the last observed value.

# %% [markdown]
# ![title](download2.jpg)

# %% [markdown]
# Here the predictions are made by assigning larger weight to the recent values and lesser weight to the old values.

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
y_pred_exp=valid.copy()
fit2=SimpleExpSmoothing(np.asarray(Train['Count'])).fit(smoothing_level=0.6,optimized=False)
y_pred_exp['SES']=fit2.forecast(len(valid))


plt.figure(figsize=(20,6))
plt.plot(Train['Count'],label='Train')
plt.plot(valid['Count'],label='Train')
plt.plot(y_pred_exp['SES'],label='SES')
plt.legend()
plt.show()

# %%
rms=sqrt(mean_squared_error(valid['Count'],y_pred_exp['SES']))
rms
# Out:
# 113.43708111884514

# %% [markdown]
# # Holt's Linear Trend Models

# %% [markdown]
# # Forecast=purwanuman

# %% [markdown]
# ---It is an extension of simple exponential smoothing to allow forecasting of data with a trend.
#
#
# ---This method takes into account the trend of the dataset. The forecast function in this method is a function of level and trend.

# %% [markdown]
# *We can decompose the time series in four parts.
#
# Observed, which is the original time series.
#
# Trend, which shows the trend in the time series, i.e., increasing or decreasing behaviour of the time series.
#
# Seasonal, which tells us about the seasonality in the time series.
#
# Residual, which is obtained by removing any trend or seasonality in the time series.

# %%
import statsmodels.api as sm

# %%
sm.tsa.seasonal_decompose(Train['Count']).plot()
plt.show()

# %% [markdown]
# An increasing trend can be seen in the dataset, so now we will make a model based on the trend.

# %%
y_pred_hat=valid.copy()
fit1=Holt(np.asarray(Train.Count)).fit(smoothing_level=0.3,smoothing_slope=0.1)
y_pred_hat['HOLT']=fit1.forecast(len(valid))

plt.figure(figsize=(20,6))
plt.plot(Train['Count'],label='Train')
plt.plot(valid['Count'],label='Train')
plt.plot(y_pred_hat['HOLT'],label='HOLT')
plt.legend()
plt.show()

# %%
rms = sqrt(mean_squared_error(valid.Count, y_pred_hat.HOLT))
print(rms)
# Out:
# 112.94278345314041

# %% [markdown]
# We can see an inclined line here as the model has taken into consideration the trend of the time series.

# %%
result=sm.tsa.stattools.adfuller(Train.Count)
result
# Out:
# (1.3873075340427332,
#  0.9970557123657253,
#  20,
#  648,
#  {'1%': -3.4404817800778034,
#   '10%': -2.569150763698369,
#   '5%': -2.866010569916275},
#  6011.151396510393)

# %% [markdown]
# Results of Dickey-Fuller Test:
# Test Statistic                    1.3873075340427332
#
#
# p-value                            0.9970557123657253
#
#
# #Lags Used                        20.000000     different observation in time series are called lags
#
#
# Number of Observations Used    648.000000
#
#
# Critical Value (1%)               -3.4404817800778034
#
#
# Critical Value (5%)               -2.866010569916275
#
#
# Critical Value (10%)              -2.866010569916275

# %% [markdown]
# # Holt’s Linear Trend Model on daily time series

# %% [markdown]
#  Now let’s try to make holt’s linear trend model on the daily time series and make predictions on the test dataset.
#
# We will make predictions based on the daily time series and then will distribute that daily prediction to hourly predictions.
#
# We have fitted the holt’s linear trend model on the train dataset and validated it using validation dataset.
#
# We have to convert these predictions to hourly basis. * To do so we will first calculate the ratio of passenger count for each hour of every day. * Then we will find the average ratio of passenger count for every hour and we will get 24 ratios. * Then to calculate the hourly predictions we will multiply the daily prediction with the hourly ratio.

# %%
#Making Prediction
prediction=fit1.forecast(len(test))

# %%
test['prediction']=prediction

# %%
# Calculating the hourly ratio of Count
train_original['ratio']=train_original.Count/train_original.Count.sum()  #means it's tell about %ge with compare to all dataset

# %%
#Grouping the hourly ratio
temp=train_original.groupby('Hour')['ratio'].sum()      #%ge of every hour ek sath

# %%
#Group by to csv
pd.DataFrame(temp).to_csv('Groupby.csv')

# %%
temp2=pd.read_csv('Groupby.csv')

# %%
temp2.head()
# Out:
#    Hour     ratio
# 0     0  0.044287
# 1     1  0.035343
# 2     2  0.029911
# 3     3  0.024714
# 4     4  0.020802

# %%
test.head()
# Out:
#                  ID    year  month   day  Hour  prediction
# Datetime
# 2014-09-26  18299.5  2014.0    9.0  26.0  11.5  334.650767
# 2014-09-27  18323.5  2014.0    9.0  27.0  11.5  337.159011
# 2014-09-28  18347.5  2014.0    9.0  28.0  11.5  339.667256
# 2014-09-29  18371.5  2014.0    9.0  29.0  11.5  342.175500
# 2014-09-30  18395.5  2014.0    9.0  30.0  11.5  344.683745

# %%
test_original.head()
# Out:
#       ID            Datetime  year  month  day  Hour
# 0  18288 2014-09-26 00:00:00  2014      9   26     0
# 1  18289 2014-09-26 01:00:00  2014      9   26     1
# 2  18290 2014-09-26 02:00:00  2014      9   26     2
# 3  18291 2014-09-26 03:00:00  2014      9   26     3
# 4  18292 2014-09-26 04:00:00  2014      9   26     4

# %%
merge=pd.merge(test,test_original,on=('day','month','year'),how='left')

# %%
merge.head()
# Out:
#       ID_x  year month day  Hour_x  prediction   ID_y            Datetime  \
# 0  18299.5  2014     9  26    11.5  334.650767  18288 2014-09-26 00:00:00
# 1  18299.5  2014     9  26    11.5  334.650767  18289 2014-09-26 01:00:00
# 2  18299.5  2014     9  26    11.5  334.650767  18290 2014-09-26 02:00:00
# 3  18299.5  2014     9  26    11.5  334.650767  18291 2014-09-26 03:00:00
# 4  18299.5  2014     9  26    11.5  334.650767  18292 2014-09-26 04:00:00
#
#    Hour_y
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4

# %%
merge['Hour']=merge['Hour_y']

# %%
merge.drop(['year','month','Datetime','Hour_x','Hour_y'],axis=1,inplace=True)

# %%
merge.head()
# Out:
#       ID_x day  prediction   ID_y  Hour
# 0  18299.5  26  334.650767  18288     0
# 1  18299.5  26  334.650767  18289     1
# 2  18299.5  26  334.650767  18290     2
# 3  18299.5  26  334.650767  18291     3
# 4  18299.5  26  334.650767  18292     4

# %%
prediction=pd.merge(merge,temp2,on=['Hour'],how='left')

# %%
prediction.head()
# Out:
#       ID_x day  prediction   ID_y  Hour     ratio
# 0  18299.5  26  334.650767  18288     0  0.044287
# 1  18299.5  26  334.650767  18289     1  0.035343
# 2  18299.5  26  334.650767  18290     2  0.029911
# 3  18299.5  26  334.650767  18291     3  0.024714
# 4  18299.5  26  334.650767  18292     4  0.020802

# %%
prediction['Count']=prediction['prediction']*prediction['ratio']*24

# %%
prediction.head()
# Out:
#       ID_x day  prediction   ID_y  Hour     ratio       Count
# 0  18299.5  26  334.650767  18288     0  0.044287  355.692974
# 1  18299.5  26  334.650767  18289     1  0.035343  283.861602
# 2  18299.5  26  334.650767  18290     2  0.029911  240.234347
# 3  18299.5  26  334.650767  18291     3  0.024714  198.497058
# 4  18299.5  26  334.650767  18292     4  0.020802  167.075574

# %%
submission=pd.read_csv('Sample_Submission_QChS6c3.csv')

# %%
submission=prediction.drop(['day','Hour','ID_x','prediction','ratio'],axis=1)

# %%
submission.head()
# Out:
#     ID_y       Count
# 0  18288  355.692974
# 1  18289  283.861602
# 2  18290  240.234347
# 3  18291  198.497058
# 4  18292  167.075574

# %%
submission.rename({'ID_y':'ID'},axis=1,inplace=True)

# %%
submission.to_csv('submission.csv',index=False)

# %% [markdown]
# # Holt winter’s model on daily time series

# %% [markdown]
# Datasets which show a similar set of pattern after fixed intervals of a time period suffer from seasonality.
#
# The above mentioned models don’t take into account the seasonality of the dataset while forecasting. Hence we need a method that takes into account both trend and seasonality to forecast future prices.
#
# One such algorithm that we can use in such a scenario is Holt’s Winter method. The idea behind Holt’s Winter is to apply exponential smoothing to the seasonal components in addition to level and trend.

# %%
y_avg_hat=valid.copy()
fit1=ExponentialSmoothing(np.asarray(Train['Count']),trend='add',seasonal='add',seasonal_periods=7).fit()  #for day repetation

# %%
y_avg_hat['Holt_winter']=fit1.forecast(len(valid))
plt.figure(figsize=(20,6))
plt.plot(Train.Count,label='Train')
plt.plot(valid.Count,label='valid')
plt.plot(y_avg_hat.Holt_winter,label='Holt_winter')
plt.legend()
plt.show()

# %%
rms=sqrt(mean_squared_error(valid.Count,y_avg_hat.Holt_winter))

# %%
rms
# Out:
# 82.37601031522233

# %%
predict=fit1.forecast(len(test))

# %%
test['prediction']=predict

# %%
test.head()
# Out:
#                  ID    year  month   day  Hour  prediction
# Datetime
# 2014-09-26  18299.5  2014.0    9.0  26.0  11.5  387.359760
# 2014-09-27  18323.5  2014.0    9.0  27.0  11.5  369.135700
# 2014-09-28  18347.5  2014.0    9.0  28.0  11.5  355.563127
# 2014-09-29  18371.5  2014.0    9.0  29.0  11.5  247.088498
# 2014-09-30  18395.5  2014.0    9.0  30.0  11.5  246.192324

# %%
test_original.head()
# Out:
#       ID            Datetime  year  month  day  Hour
# 0  18288 2014-09-26 00:00:00  2014      9   26     0
# 1  18289 2014-09-26 01:00:00  2014      9   26     1
# 2  18290 2014-09-26 02:00:00  2014      9   26     2
# 3  18291 2014-09-26 03:00:00  2014      9   26     3
# 4  18292 2014-09-26 04:00:00  2014      9   26     4

# %%
merge=pd.merge(test,test_original,on=['year','month','day'],how='left')

# %%
merge.head(2)
# Out:
#       ID_x  year month day  Hour_x  prediction   ID_y            Datetime  \
# 0  18299.5  2014     9  26    11.5   387.35976  18288 2014-09-26 00:00:00
# 1  18299.5  2014     9  26    11.5   387.35976  18289 2014-09-26 01:00:00
#
#    Hour_y
# 0       0
# 1       1

# %%
merge['Hour']=merge['Hour_y']
merge.drop(['year','day','month','Hour_x','Hour_y','ID_x','Datetime'],axis=1,inplace=True)

# %%
merge.head(2)
# Out:
#    prediction   ID_y  Hour
# 0   387.35976  18288     0
# 1   387.35976  18289     1

# %%
merge.rename({'ID_y':'ID'},axis=1,inplace=True)

# %%
merge.head(2)
# Out:
#    prediction     ID  Hour
# 0   387.35976  18288     0
# 1   387.35976  18289     1

# %%
temp2.head(2)
# Out:
#    Hour     ratio
# 0     0  0.044287
# 1     1  0.035343

# %%
prediction=pd.merge(merge,temp2,on=['Hour'],how='left')

# %%
prediction.head(2)
# Out:
#    prediction     ID  Hour     ratio
# 0   387.35976  18288     0  0.044287
# 1   387.35976  18289     1  0.035343

# %%
prediction['Count']=prediction['prediction']*prediction['ratio']*24

# %%
prediction.head(2)
# Out:
#    prediction     ID  Hour     ratio       Count
# 0   387.35976  18288     0  0.044287  411.716209
# 1   387.35976  18289     1  0.035343  328.571074

# %%
submission1=pd.DataFrame(prediction,columns=['ID','Count'])

# %%
submission1.head(2)
# Out:
#       ID       Count
# 0  18288  411.716209
# 1  18289  328.571074

# %%
submission1.to_csv('submission1.csv',index=False)

# %% [markdown]
#  this model was not that good in predicting the trend of the time series but worked really well on the seasonality part.
#
#
#  (from leaderboard 333.) so not good

# %% [markdown]
# Till now we have made different models for trend and seasonality

# %% [markdown]
#   ARIMA model for time series forecasting for both trend and seasonality

# %% [markdown]
# # Introduction to ARIMA model

# %% [markdown]
# link:)https://towardsdatascience.com/arima-forecasting-vocabulary-ec9b09d55be7
#
#
# https://www.analyticsvidhya.com/blog/2015/12/complete-tutorial-time-series-modeling/

# %% [markdown]
# # Lags=अंतराल (antaraal)

# %% [markdown]
# ARIMA stands for Auto Regression Integrated Moving Average. It is specified by three ordered parameters (p,d,q).
#
# Here p is the order of the autoregressive model(number of time lags)
#
# d is the degree of differencing(number of times the data have had past values subtracted)
#
# q is the order of moving average model.
#
# The ARIMA forecasting for a stationary time series is nothing but a linear (like a linear regression) equation.

# %% [markdown]
# # What is a stationary time series?
#
# There are three basic criterion for a series to be classified as stationary series :
#
# The mean of the time series should not be a function of time. It should be constant.
#
# The variance of the time series should not be a function of time.
#
# THe covariance of the ith term and the (i+m)th term should not be a function of time.

# %% [markdown]
# # Why do we have to make the time series stationary?
#
# We make the series stationary to make the variables independent. Variables can be dependent in various ways, but can only be independent in one way. So, we will get more information when they are independent. Hence the time series must be stationary.
#
# If the time series is not stationary, firstly we have to make it stationary. For doing so, we need to remove the trend and seasonality from the data#

# %% [markdown]
# # Parameter tuning for ARIMA model

# %% [markdown]
# First of all we have to make sure that the time series is stationary. If the series is not stationary, we will make it stationary.

# %% [markdown]
# ## Stationarity Check
# ### Dickey Fuller test t

# %% [markdown]
# Null Hypothesis (H0): If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
#
#
# Alternate Hypothesis (H1): The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.

# %% [markdown]
# p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
#
# p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.

# %% [markdown]
# -------------------------------------------------
#
# The test results comprise of a Test Statistic and some Critical Values for difference confidence levels.
#
# If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is
# stationary.

# %% [markdown]
# -----------------------------------------------------------------------------------------
#
# We interpret this result using the Test Statistics and critical value. If the Test Statistics is smaller than critical value, it suggests we reject the null hypothesis (stationary), otherwise a greater Test Statistics suggests we accept the null hypothesis (non-stationary).

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    #Determine rolling statistics
    rolmean=pd.rolling_mean(timeseries,window=24)
    rolstd=pd.rolling_std(timeseries,window=24)
    
    #plot rolling statistics
    plt.figure(figsize=(20,5))
    plt.plot(timeseries,color='blue',label='Original')
    plt.plot(rolmean,color='red',label='Rolling Mean')
    plt.plot(rolstd,color='black',label='Rolling Std')
    plt.title('Rolling Mean & Standard Deviation')
    plt.legend()
    plt.show()
    
    
    #Dickey-fuller test
    print('Result Of Dickey-fuller Test:')
    dftest=adfuller(timeseries)
    dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','Number Of Observation Used'])
    
    for key,value in dftest[4].items():
        dfoutput['Critical value (%s)'%key]=value
    print(dfoutput)

# %%
train_original.head(2)
# Out:
#    ID            Datetime  Count  year  month  day  Hour         ratio
# 0   0 2012-08-25 00:00:00      8  2012      8   25     0  3.148037e-06
# 1   1 2012-08-25 01:00:00      2  2012      8   25     1  7.870093e-07

# %%
plt.figure(figsize=(20,10))
test_stationarity(train_original.Count)
# Out:
# Result Of Dickey-fuller Test:
# Test Statistic                   -4.456561
# p-value                           0.000235
# #lags used                       45.000000
# Number Of Observation Used    18242.000000
# Critical value (1%)              -3.430709
# Critical value (5%)              -2.861698
# Critical value (10%)             -2.566854
# dtype: float64

# %% [markdown]
# The statistics shows that the time series is stationary as Test Statistic < Critical value but we can see an increasing trend in the data. So, firstly we will try to make the data more stationary. For doing so, we need to remove the trend and seasonality from the data.

# %% [markdown]
# #### Removing Trend
# A trend exists when there is a long-term increase or decrease in the data. It does not have to be linear.
#
# We see an increasing trend in the data so we can apply transformation which penalizes higher values more than smaller ones, for example log transformation.
#
# We will take rolling average here to remove the trend. We will take the window size of 24 based on the fact that each day has 24 hours.

# %%
Train_log=np.log(Train['Count'])
valid_log=np.log(valid['Count'])

# %%
moving_avg=pd.rolling_mean(Train_log,24)
plt.figure(figsize=(20,6))
plt.plot(Train_log,label='Train_log')
plt.plot(moving_avg,label='Moving _avg')
plt.legend()
plt.show()

# %% [markdown]
# So we can observe an increasing trend. Now we will remove this increasing trend to make our time series stationary.

# %%
train_log_moving_avg_diff=Train_log-moving_avg

# %%
train_log_moving_avg_diff.dropna(inplace=True)

# %%
plt.figure(figsize=(20,5))
test_stationarity(train_log_moving_avg_diff)
# Out:
# Result Of Dickey-fuller Test:
# Test Statistic               -5.861646e+00
# p-value                       3.399422e-07
# #lags used                    2.000000e+01
# Number Of Observation Used    6.250000e+02
# Critical value (1%)          -3.440856e+00
# Critical value (5%)          -2.866175e+00
# Critical value (10%)         -2.569239e+00
# dtype: float64

# %% [markdown]
# We can see that the Test Statistic is very smaller as compared to the Critical Value. So, we can be confident that the trend is almost removed.

# %% [markdown]
# stabilize the mean of the time series which is also a requirement for a stationary time series.

# %% [markdown]
# Differencing can help to make the series stable and eliminate the trend.

# %%
Train.Count.head()
# Out:
# Datetime
# 2012-08-25    3.166667
# 2012-08-26    3.666667
# 2012-08-27    2.583333
# 2012-08-28    2.416667
# 2012-08-29    2.500000
# Freq: D, Name: Count, dtype: float64

# %%
Train_log.head(3)
# Out:
# Datetime
# 2012-08-25    1.152680
# 2012-08-26    1.299283
# 2012-08-27    0.949081
# Freq: D, Name: Count, dtype: float64

# %%
Train_log.shift(1).head(3)
# Out:
# Datetime
# 2012-08-25         NaN
# 2012-08-26    1.152680
# 2012-08-27    1.299283
# Freq: D, Name: Count, dtype: float64

# %%
Train_log.tail(3)
# Out:
# Datetime
# 2014-06-22    5.441696
# 2014-06-23    6.038865
# 2014-06-24    5.919342
# Freq: D, Name: Count, dtype: float64

# %%
Train_log.shift(1).tail(3)
# Out:
# Datetime
# 2014-06-22    5.394006
# 2014-06-23    5.441696
# 2014-06-24    6.038865
# Freq: D, Name: Count, dtype: float64

# %%
train_log_diff=Train_log-Train_log.shift(1)

# %%
train_log_shift.head(2)
# Out:
# Datetime
# 2012-08-25         NaN
# 2012-08-26    0.146603
# Freq: D, Name: Count, dtype: float64

# %%
train_log_shift.tail(2)
# Out:
# Datetime
# 2014-06-23    0.597169
# 2014-06-24   -0.119523
# Freq: D, Name: Count, dtype: float64

# %%
test_stationarity(train_log_shift.dropna())
# Out:
# Result Of Dickey-fuller Test:
# Test Statistic               -8.237568e+00
# p-value                       5.834049e-13
# #lags used                    1.900000e+01
# Number Of Observation Used    6.480000e+02
# Critical value (1%)          -3.440482e+00
# Critical value (5%)          -2.866011e+00
# Critical value (10%)         -2.569151e+00
# dtype: float64

# %% [markdown]
# Now we will decompose the time series into trend and seasonality and will get the residual which is the random variation in the series.

# %% [markdown]
# ##### Removing Seasonality

# %% [markdown]
# By seasonality, we mean periodic fluctuations. A seasonal pattern exists when a series is influenced by seasonal factors (e.g., the quarter of the year, the month, or day of the week).

# %% [markdown]
# Seasonality is always of a fixed and known period.

# %% [markdown]
# We will use seasonal decompose to decompose the time series into trend, seasonality and residuals.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition=seasonal_decompose(pd.DataFrame(Train_log).Count.values,freq=24)

trend=decomposition.trend
seasonal=decomposition.seasonal
residual=decomposition.resid

plt.figure(figsize=(20,10))
plt.subplot(411)
plt.plot(Train_log,label='Original')
plt.legend()
plt.subplot(412)
plt.plot(trend,label='Trend')
plt.legend()
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend()
plt.subplot(414)
plt.plot(residual,label='Residuals')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see the trend, residuals and the seasonality clearly in the above graph. Seasonality shows a constant trend in counter.

# %% [markdown]
# Let’s check stationarity of residuals

# %%
train_log_decompose=pd.DataFrame(residual)
train_log_decompose['date']=Train_log.index
train_log_decompose.set_index('date',inplace=True)
train_log_decompose.dropna(inplace=True)

# %%
train_log_decompose.head(3)
# Out:
#                    0
# date
# 2012-09-06  0.153628
# 2012-09-07 -0.228164
# 2012-09-08  0.133681

# %%
test_stationarity(train_log_decompose[0])
# Out:
# Result Of Dickey-fuller Test:
# Test Statistic               -7.822096e+00
# p-value                       6.628321e-12
# #lags used                    2.000000e+01
# Number Of Observation Used    6.240000e+02
# Critical value (1%)          -3.440873e+00
# Critical value (5%)          -2.866183e+00
# Critical value (10%)         -2.569243e+00
# dtype: float64

# %% [markdown]
# It can be interpreted from the results that the residuals are stationary.
#
# Now we will forecast the time series using different models.

# %% [markdown]
# #### Forecasting the time series using ARIMA

# %% [markdown]
# First of all we will fit the ARIMA model on our time series for that we have to find the optimized values for the p,d,q parameters.
#
# To find the optimized values of these parameters, we will use ACF(Autocorrelation Function) and PACF(Partial Autocorrelation Function) graph.
#
# ACF is a measure of the correlation between the TimeSeries with a lagged version of itself.
#
# PACF measures the correlation between the TimeSeries with a lagged version of itself but after eliminating the variations already explained by the intervening comparisons.
#
# ###### OR
# The autocorrelation function (ACF) measures how a series is correlated with itself at different lags

# %% [markdown]
# Suppose you have 3 points in a time series x3 - x2 - x1. Using ACF you would generally find the correlation between x1 and x2 , for example. The value of correlation thus obtained is technically not true value of correlation, because the value of x2 is likely to be inspired by the value of x3.

# %% [markdown]
# PACF is that portion of the correlation between x1 and x2, which is not explained by the correlation between x3 in x2.

# %% [markdown]
# lets say, the correlation between x1 and x2 is given by the PINK box(including the GREEN box), and the correlation between x2 and x3 is given by the GREEN box. So the partial correlation of x1 and x2 is the original correlation minus the correlation of x2 and x3(GREEN box), which is just the PINK Pentagon.
# ![title](1.webp)

# %%
from statsmodels.tsa.stattools import acf,pacf
lag_acf=acf(train_log_diff.dropna(),nlags=25)
lag_pacf=pacf(train_log_diff.dropna(),nlags=25,method='ols')

# %%
pd.DataFrame(lag_acf).head()
# Out:
#           0
# 0  1.000000
# 1 -0.127510
# 2 -0.371556
# 3 -0.002014
# 4  0.042512

# %%
pd.DataFrame(lag_pacf).head()
# Out:
#           0
# 0  1.000000
# 1 -0.127530
# 2 -0.395444
# 3 -0.142841
# 4 -0.162244

# %% [markdown]
# ##### ACF and PACF plot

# %%
plt.figure(figsize=(20,10))
plt.plot(lag_acf)
plt.axhline(y=-1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(lag_pacf)
plt.axhline(y=-1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.show()

# %% [markdown]
# p value is the lag value where the PACF chart crosses the upper confidence interval for the first time. It can be noticed that in this case p=1.
#
# q value is the lag value where the ACF chart crosses the upper confidence interval for the first time. It can be noticed that in this case q=1.

# %% [markdown]
# Now we will make the ARIMA model as we have the p,q values. We will make the AR and MA model separately and then combine them together.

# %% [markdown]
# ###### AR model

# %% [markdown]
# The autoregressive model specifies that the output variable depends linearly on its own previous values.

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(Train_log,order=(2,1,0))  #for AR q is 0
result_AR=model.fit()

# %%
result_AR.fittedvalues.head(2)
# Out:
# Datetime
# 2012-08-26    0.007041
# 2012-08-27   -0.010701
# Freq: D, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(train_log_diff.dropna(),label='Original')
plt.plot(result_AR.fittedvalues,color='red',label='Prediction')
plt.legend()
plt.show()

# %% [markdown]
# Lets plot the validation curve for AR model.
#
# We have to change the scale of the model to the original scale.
#
# First step would be to store the predicted results as a separate series and observe it.

# %%
AR_predict=result_AR.predict(start='2014-06-25',end='2014-09-25')

# %%
AR_predict.head()
# Out:
# 2014-06-25   -0.203497
# 2014-06-26    0.094338
# 2014-06-27    0.074681
# 2014-06-28   -0.039417
# 2014-06-29   -0.011425
# Freq: D, dtype: float64

# %%
AR_predict=AR_predict.cumsum()
AR_predict.head()
# Out:
# 2014-06-25   -0.203497
# 2014-06-26   -0.109158
# 2014-06-27   -0.034477
# 2014-06-28   -0.073894
# 2014-06-29   -0.085319
# Freq: D, dtype: float64

# %%
AR_predict=AR_predict.shift().fillna(0)
AR_predict.head()
# Out:
# 2014-06-25    0.000000
# 2014-06-26   -0.203497
# 2014-06-27   -0.109158
# 2014-06-28   -0.034477
# 2014-06-29   -0.073894
# Freq: D, dtype: float64

# %%
AR_predict1=pd.Series(np.ones(valid.Count.shape)*np.log(valid.Count)[0],index=valid.index)

# %%
AR_predict1.head()
# Out:
# Datetime
# 2014-06-25    5.868355
# 2014-06-26    5.868355
# 2014-06-27    5.868355
# 2014-06-28    5.868355
# 2014-06-29    5.868355
# Freq: D, dtype: float64

# %%
AR_predict1=AR_predict.add(AR_predict1,fill_value=0)
AR_predict1.head()
# Out:
# 2014-06-25    5.868355
# 2014-06-26    5.664858
# 2014-06-27    5.759197
# 2014-06-28    5.833878
# 2014-06-29    5.794461
# Freq: D, dtype: float64

# %%
AR_predict=np.exp(AR_predict1)
AR_predict.head()
# Out:
# 2014-06-25    353.666667
# 2014-06-26    288.547034
# 2014-06-27    317.093464
# 2014-06-28    341.681155
# 2014-06-29    328.475169
# Freq: D, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(valid.Count,label='Actual')
plt.plot(AR_predict,color='red',label='Prediction')
plt.title('RMSE:%.4f'%((np.sqrt(np.dot(AR_predict, valid['Count'])))/valid.shape[0]))
plt.legend()
plt.show()

# %%
AR_predict.head()
# Out:
# 2014-06-25    353.666667
# 2014-06-26    288.547034
# 2014-06-27    317.093464
# 2014-06-28    341.681155
# 2014-06-29    328.475169
# Freq: D, dtype: float64

# %%
valid.Count.head()
# Out:
# Datetime
# 2014-06-25    353.666667
# 2014-06-26    395.250000
# 2014-06-27    282.333333
# 2014-06-28    218.250000
# 2014-06-29    196.250000
# Freq: D, Name: Count, dtype: float64

# %%
sqrt(np.dot(AR_predict,valid.Count))/93
# Out:
# 43.97400028844397

# %% [markdown]
# ##### MA model
# The moving-average model specifies that the output variable depends linearly on the current and various past values of a stochastic (imperfectly predictable) term.

# %%
model=ARIMA(Train_log,order=(0,1,2))
results_MA=model.fit()
plt.figure(figsize=(20,10))
plt.plot(train_log_diff.dropna(),label='Original')
plt.plot(results_MA.fittedvalues,color='red',label='Prediction')
plt.legend()
plt.show()

# %%
MA_predict=results_MA.predict(start='2014-06-25',end='2014-09-25')
MA_predict=MA_predict.cumsum().shift().fillna(0)
MA_predict1=pd.Series(np.ones(valid.shape[0])*np.log(valid.Count)[0],index=valid.index)
MA_predict1=MA_predict1.add(MA_predict,fill_value=0)
MA_predict=np.exp(MA_predict1)

# %%
plt.figure(figsize=(20,10))
plt.plot(valid.Count,label='Actual')
plt.plot(MA_predict,color='red',label='Prediction')
plt.title('RMSE: %.4f'%(np.sqrt(np.dot(valid.Count,MA_predict))/valid.shape[0]))
plt.legend()
plt.show()

# %% [markdown]
# Now let’s combine these two models

# %% [markdown]
# #### Combined Model

# %%
plt.figure(figsize=(20,8))
model=ARIMA(Train_log,order=(2,1,2))
results_ARIMA=model.fit(disp=-1)
plt.plot(train_log_diff,label='Actual')
plt.plot(results_ARIMA.fittedvalues,color='red',label='Prediction')
plt.legend()
plt.show()

# %%
def check_prediction_diff(predict_diff,given_set):
    predict_diff=predict_diff.cumsum().shift().fillna(0)
    predict_base=pd.Series(np.ones(given_set.shape[0])*np.log(given_set['Count'])[0],index=given_set.index)
    predict_log=predict_base.add(predict_diff,fill_value=0)
    predict=np.exp(predict_log)
    
    plt.figure(figsize=(20,8))
    plt.plot(given_set.Count,label='Actual')
    plt.plot(predict,color='red',label='Prediction')
    plt.title('RMSE: %.4f'% (np.sqrt(np.dot(given_set.Count,predict))/given_set.shape[0]))
    plt.legend()
    plt.show()

# %%
def check_prediction_log(predict_log,given_set):
    predict=np.exp(predict_log)
    
    plt.plot(given_set.Count,label='Actual')
    plt.plot(predict,color='red',label='prediction')
    plt.figure(figsize=(20.8))
    plt.title('RMSE: %.4f'% (np.sqrt(np.dot(given_set.Count,predict))/given_set.shape[0]))
    plt.legend()
    plt.show()

# %%
ARIMA_predict_diff=results_ARIMA.predict(start='2014-06-25',end='2014-09-25')

# %%
check_prediction_diff(ARIMA_predict_diff,valid)

# %% [markdown]
# # SARIMAX model on daily time series

# %% [markdown]
# SARIMAX model takes into account the seasonality of the time series. So we will build a SARIMAX model on the time series.

# %%
import statsmodels.api as sm

# %% [markdown]
# seasonal_order (iterable, optional) – The (P,D,Q,s) order of the seasonal component of the model for the AR parameters, differences, MA parameters, and periodicity. d must be an integer indicating the integration order of the process, while p and q may either be an integers indicating the AR and MA orders (so that all lags up to those orders are included) or else iterables giving specific AR and / or MA lags to include. s is an integer giving the periodicity (number of periods in season), often it is 4 for quarterly data or 12 for monthly data. Default is no seasonal effect.

# %%
y_hat_avg=valid.copy()
fit1=sm.tsa.statespace.SARIMAX(Train.Count,order=(2,1,4),seasonal_order=(0,1,1,7)).fit()
y_hat_avg['SARIMA']=fit1.predict(start='2014-06-25',end='2014-09-25',dynamic=True)
plt.figure(figsize=(20,8))
plt.plot(Train.Count,label='Train')
plt.plot(valid.Count,label='valid')
plt.plot(y_hat_avg['SARIMA'],label='SARIMA')
plt.legend()
plt.show()

# %% [markdown]
# Order in the above model represents the order of the autoregressive model(number of time lags), the degree of differencing(number of times the data have had past values subtracted) and the order of moving average model.
#
# Seasonal order represents the order of the seasonal component of the model for the AR parameters, differences, MA parameters, and periodicity.
#
# In our case the periodicity is 7 since it is daily time series and will repeat after every 7 days.

# %%
rms=sqrt(mean_squared_error(valid.Count,y_hat_avg.SARIMA))

# %%
rms
# Out:
# 70.1359921531265

# %% [markdown]
# forecasting the time series for Test data which starts from 2014-9-26 and ends at 2015-4-26.

# %%
predict=fit1.predict(start='2014-09-26',end='2015-04-26',dynamic=True)

# %% [markdown]
# these are the daily predictions and we need hourly predictions. So, we will distribute this daily prediction into hourly counts. To do so, we will take the ratio of hourly distribution of passenger count from train data and then we will distribute the predictions in the same ratio.

# %%
test['prediction']=predict

# %%
plt.plot(predict)

# %% [markdown]
# ------------merge test and test_original on day,month and year

# %%
test.head(2)
# Out:
#                  ID    year  month   day  Hour  prediction
# Datetime
# 2014-09-26  18299.5  2014.0    9.0  26.0  11.5  452.345195
# 2014-09-27  18323.5  2014.0    9.0  27.0  11.5  343.667183

# %%
test_original.head(2)
# Out:
#       ID            Datetime  year  month  day  Hour
# 0  18288 2014-09-26 00:00:00  2014      9   26     0
# 1  18289 2014-09-26 01:00:00  2014      9   26     1

# %%
merge=pd.merge(test,test_original,on=['year','month','day'],how='left')

# %%
merge.head(2)
# Out:
#       ID_x  year month day  Hour_x  prediction   ID_y            Datetime  \
# 0  18299.5  2014     9  26    11.5  452.345195  18288 2014-09-26 00:00:00
# 1  18299.5  2014     9  26    11.5  452.345195  18289 2014-09-26 01:00:00
#
#    Hour_y
# 0       0
# 1       1

# %%
merge['Hour']=merge['Hour_y']

# %%
merge.head(2)
# Out:
#       ID_x  year month day  Hour_x  prediction   ID_y            Datetime  \
# 0  18299.5  2014     9  26    11.5  452.345195  18288 2014-09-26 00:00:00
# 1  18299.5  2014     9  26    11.5  452.345195  18289 2014-09-26 01:00:00
#
#    Hour_y  Hour
# 0       0     0
# 1       1     1

# %%
merge.drop(['year','month','Datetime','Hour_x','Hour_y'],axis=1,inplace=True)

# %%
merge.head(2)
# Out:
#       ID_x day  prediction   ID_y  Hour
# 0  18299.5  26  452.345195  18288     0
# 1  18299.5  26  452.345195  18289     1

# %%
temp2.head(2)
# Out:
#    Hour     ratio
# 0     0  0.044287
# 1     1  0.035343

# %% [markdown]
# Predicting by merging merge and temp2

# %%
prediction=pd.merge(merge,temp2,on=['Hour'],how='left')

# %%
prediction.head(2)
# Out:
#       ID_x day  prediction   ID_y  Hour     ratio
# 0  18299.5  26  452.345195  18288     0  0.044287
# 1  18299.5  26  452.345195  18289     1  0.035343

# %% [markdown]
#  Converting the ratio to the original scale

# %%
prediction['Count']=prediction['prediction']*prediction['ratio']*24

# %%
prediction.head(2)
# Out:
#       ID_x day  prediction   ID_y  Hour     ratio       Count
# 0  18299.5  26  452.345195  18288     0  0.044287  480.787806
# 1  18299.5  26  452.345195  18289     1  0.035343  383.693822

# %%
prediction['ID']=prediction['ID_y']

# %% [markdown]
# drop all variables other than ID and Count

# %%
prediction.drop(['ID_x','day','prediction','Hour','ratio','ID_y'],axis=1,inplace=True)

# %%
prediction.head()
# Out:
#         Count     ID
# 0  480.787806  18288
# 1  383.693822  18289
# 2  324.723154  18290
# 3  268.307141  18291
# 4  225.834932  18292

# %%
pd.DataFrame(prediction,columns=['ID','Count']).to_csv('SARIMAX.csv',index=False)

# %% [markdown]
# method gave us the least rmse score. The rmse on the test is 219.095.
